# %%
#int
45
5
10
12
#float
5.6
8.7
#string
"Jafare"
'Cow'
'Ileya'
#list
[3, 5, 6.7, [6,7]]
#tuple
(3, 4, 5)
#Boolean
True and False
#dict
{
    'name' : "Ha",
    'age' : 56
}

# %%
# +, -, /, %, *, **

2 ** 5
5/2
5%2
5 * 2

# %%
# variable

jafar1 = 52
jafar_coder = 5
_name = "Lihammed"
# &jafar, 5gags

# %%
userInput = input('Enter your name')

print("User's name is", userInput)
# Out:
# User's name is Jafarscript

# %%
userNumeber = float(input('Enter a number'))

print(userNumeber ** 5)
# Out:
# 5507.317759999998

# %%
def multiply(a,b):
    return a * b
multiply(56, 2)
# Out:
# 112

# %%
# >, <, =>, =<, or, and, in
# if , else , elif



if 10 < 5:
    print("yes")
else:
    print("no")


if 10 in ['name', 10, 5]:
    print('It is')
else:
    print('It is not')
# Out:
# no
# It is

# %%
# for loop and while loop
count = 10

while count < 100:
    print(2 ** count )
    count += 1
# Out:
# 1024
# 2048
# 4096
# 8192
# 16384
# 32768
# 65536
# 131072
# 262144
# 524288
# 1048576
# 2097152
# 4194304
# 8388608
# 16777216
# 33554432
# 67108864
# 134217728
# 268435456
# 536870912
# 1073741824
# 2147483648
# 4294967296
# 8589934592
# 17179869184
# 34359738368
# 68719476736
# 137438953472
# 274877906944
# 549755813888
# 1099511627776
# 2199023255552
# 4398046511104
# 8796093022208
# 17592186044416
# 35184372088832
# 70368744177664
# 140737488355328
# 281474976710656
# 562949953421312
# 1125899906842624
# 2251799813685248
# 4503599627370496
# 9007199254740992
# 18014398509481984
# 36028797018963968
# 72057594037927936
# 144115188075855872
# 288230376151711744
# 576460752303423488
# 1152921504606846976
# 2305843009213693952
# 4611686018427387904
# 9223372036854775808
# 18446744073709551616
# 36893488147419103232
# 73786976294838206464
# 147573952589676412928
# 295147905179352825856
# 590295810358705651712
# 1180591620717411303424
# 2361183241434822606848
# 4722366482869645213696
# ...

# %%
print(2 ** 99)
# Out:
# 633825300114114700748351602688

# %%
for x in range(1, 101):
    print(x ** 2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744
# 7921
# 8100
# 8281
# 8464
# 8649
# 8836
# 9025
# 9216
# 9409
# 9604
# 9801
# 10000
